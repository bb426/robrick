# %% [markdown]
# # RobinBrick Event Calendar

# %%
# Note : Need to find substitutional solution for cities without a airport
# place.scope

# %%
import requests
import pandas as pd

# %%
api_host = 'https://api.predicthq.com'
path = '/v1/events/'

# %%
def req(url, headers, params, query, method, payload={}):
    
    print('HTTP Method: %s' % method)
    print('Request URL: %s' % url)
    print('Headers: %s' % headers)
    print('QueryString: %s' % query)

    if method == 'GET':
        return requests.get(url, headers=headers, params=params)
    else:
        return requests.post(url, headers=headers, json=data)

# %%
headers = {'Authorization': 'Bearer DzPJDgQYrJmXjiSktKrxGpaXSwxBz3',
           'Accept': 'application/json',
           'Content-Type': 'application/json'}
params = {'country':'ES',
          "start": "2019-02-01T00:00:00Z",
          "end": "2019-03-31T23:59:59Z",
          'place.scope':'BCN'
#           'within':'10000m@2.170951,41.387137'
#           'timezone':'Europe/Madrid',
#           'active.gte':'2019-02-01', 
#           'active.lte':'2019-03-31',
#           'location':'@2.170951,41.387137',
#           'location_around.origin':'2.170951,41.387137' ###not working
         }

# %%
resp = req(url=api_host+path, headers=headers, params=params, query='', method='GET')
# Out:
# HTTP Method: GET
# Request URL: https://api.predicthq.com/v1/events/
# Headers: {'Authorization': 'Bearer DzPJDgQYrJmXjiSktKrxGpaXSwxBz3', 'Accept': 'application/json', 'Content-Type': 'application/json'}
# QueryString:

# %%
result = pd.DataFrame(resp.json()['results'])

# %%
result
# Out:
#     category country                                        description  \
# 0   concerts      ES
# 1   concerts      ES
# 2   concerts      ES
# 3   concerts      ES
# 4   concerts      ES
# 5  festivals      ES
# 6   concerts      ES
# 7   concerts      ES  MR SHINGLES\n\nMr Shingles, guitarra, harmónic...
# 8   concerts      ES  Every Tuesday and Thursday, The Pumpage Networ...
# 9   concerts      ES  Palau Dalmases is located on Barcelona’s popul...
#
#    duration                   end            first_seen                  id  \
# 0     21660  2019-05-01T04:00:00Z  2019-03-24T01:14:24Z  XcbCikgdyPmQuhcWa9
# 1     21660  2019-05-01T04:00:00Z  2019-03-31T00:28:50Z  3HjzmHHJfV23cYEGbr
# 2     21660  2019-05-01T04:00:00Z  2019-02-10T20:21:05Z  nfiBNJMaxonUJgw64N
# 3     18060  2019-05-01T03:00:00Z  2019-03-10T06:21:45Z  yPWa8MP3CSmJvpwyAz
# 4         0  2019-04-30T21:00:00Z  2019-03-25T19:55:02Z  TGea8TX348RK7XMuky
# ...
